# %% [markdown]
# # Canada's Response to Economic Impacts of COVID-19
#
# Amanda Cheney
# Metis Final Project
# Part 1 of 4
# December 8, 2020
#
# **Objective**
# Unsupervised learning and natural language processing to identify two sets of clusters of Twitter conversations about the Canadian Emergency Response Benefit (CERB) and Canadian Recovery Benefit(CRB) programs to address unemployment and economic impacts of the COVID-19 pandemic.
#
# 1. One that captures the contours of everyday user conversations.
#
# 2.  Another that highlights clusters of conversation that are really, really dense, have users make collaborative efforts to shape public opinion and perception.
#
# **Data Sources**
# 250,000+ tweets from March 1 - December 1, 2020, collected using snscrape.
#
# **This Notebook**
# Collects tweets, intial EDA and cleaning.

# %% [markdown]
# ## Imports

# %%
import json
import csv
import pandas as pd
import pickle

# %% [markdown]
# ## Twitter Query

# %% [markdown]
# The Twitter API limits developers to tweets from within the past week. Yet I wanted to collect tweets from as far back as March 2020, when the pandemic first began and these programs were first rolled out, to the present. So for my historical tweet collection, I used [snscrape](https://github.com/JustAnotherArchivist/snscrape).  Snscrape offers somewhat less  metadata than the Twitter API itself, however, it still offered me more than enough for the purposes of this analysis.
#
# To ensure that my Twitter results did not contain too many extraneous tweets, I used a relatively complex search query. It gathers tweets since March 1, 2020, filters out retweets and content associated with the term CERB and CRB unrelated to these Canadian temporary social security and financial aid programs.

# %% [markdown]
# snscape call is made at command line `snscrape --jsonl --max-results 2000000 --since 2020-03-01 twitter-search '((CRB or #CRB) -clubes -coupe -SuperCoupe -SUPER_COUPE -football -belouizdad -chabab -USMA -brasileño -Brasileirão -Algérie -Railway -@IR_CRB -@RailMinIndia -@PiyushGoyal) OR CERB OR #CERB OR (#EI (Canada OR #onpoli OR #cdnpoli)) OR (Canada unemployment) OR ((#CRA or cra) (#covid19canada OR #covid19relief OR covid OR covid19 OR coronavirus or pandemic)) -filter:retweets' > cerb_no_retweets.json`

# %%
cerb_df = pd.read_json('cerb_no_retweets.json', lines=True)

# %%
cerb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255327 entries, 0 to 255326
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              255327 non-null  object
#  1   date             255327 non-null  datetime64[ns, UTC]
#  2   content          255327 non-null  object
#  3   renderedContent  255327 non-null  object
#  4   id               255327 non-null  int64
#  5   user             255327 non-null  object
#  6   outlinks         255327 non-null  object
#  7   tcooutlinks      255327 non-null  object
#  8   replyCount       255327 non-null  int64
#  9   retweetCount     255327 non-null  int64
#  10  likeCount        255327 non-null  int64
#  11  quoteCount       255327 non-null  int64
#  12  conversationId   255327 non-null  int64
#  13  lang             255327 non-null  object
#  14  source           255327 non-null  object
#  15  sourceUrl        255323 non-null  object
#  16  sourceLabel      255323 non-null  object
#  17  media            18546 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      22020 non-null   object
#  20  mentionedUsers   162972 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 40.9+ MB

# %% [markdown]
# Note that `retweetedTweet` has 0 non-null rows, which we should expect having filtered out retweets.

# %%
cerb_df.shape
# Out:
# (255327, 21)

# %% [markdown]
# Next step is to limit to English language only tweets. Although Canada is officially a bilingual country, the French language equivalents of CERB and CRB have different names and acronyms - Prestation canadienne d’urgence (PCU) and Prestation canadienne de la relance économique (PCRE). Sifting through the noise of Twitter for these is beyond the scope of this project but would be an excellent avenue of future work.

# %%
cerb_df = cerb_df[cerb_df['lang']=='en']

# %%
cerb_df.shape
# Out:
# (240808, 21)

# %%
cerb_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/SandraLynnColl3/status/133...
# 2  https://twitter.com/bunmzi/status/133356432966...
# 3  https://twitter.com/D313131Daniel/status/13335...
# 4  https://twitter.com/Paulbyjove1/status/1333563...
# 5  https://twitter.com/GavinBamber/status/1333563...
#
#                        date  \
# 0 2020-12-01 00:12:39+00:00
# 2 2020-12-01 00:11:27+00:00
# 3 2020-12-01 00:08:32+00:00
# 4 2020-12-01 00:07:28+00:00
# 5 2020-12-01 00:07:00+00:00
#
#                                              content  \
# 0  @mini_bubbly In our Entire extended family, on...
# 2  @MrStache9 Many Canadians dont realize this. L...
# 3  @nationalpost @TheGrowthOp So that won’t cost ...
# 4  @exposforever @MJosling53 @erinotoole @PierreP...
# 5  @journo_dale Something like over $400 million ...
#
#                                      renderedContent                   id  \
# 0  @mini_bubbly In our Entire extended family, on...  1333564633320480769
# 2  @MrStache9 Many Canadians dont realize this. L...  1333564329665441793
# 3  @nationalpost @TheGrowthOp So that won’t cost ...  1333563595607699464
# 4  @exposforever @MJosling53 @erinotoole @PierreP...  1333563328040464385
# 5  @journo_dale Something like over $400 million ...  1333563211216424961
#
#                                                 user outlinks tcooutlinks  \
# 0  {'username': 'SandraLynnColl3', 'displayname':...       []          []
# 2  {'username': 'bunmzi', 'displayname': 'Mikel A...       []          []
# 3  {'username': 'D313131Daniel', 'displayname': '...       []          []
# 4  {'username': 'Paulbyjove1', 'displayname': 'Pa...       []          []
# 5  {'username': 'GavinBamber', 'displayname': 'Ga...       []          []
#
#    replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0           0             0  ...           0  1333538159846715392    en
# 2           0             1  ...           0  1333526557697187847    en
# 3           0             0  ...           0  1333472122270851073    en
# 4           0             0  ...           0  1333380605426495489    en
# 5           0             0  ...           0  1333549485725798400    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="https://mobile.twitter.com" rel="nofo...
#
#                              sourceUrl          sourceLabel media  \
# 0  http://twitter.com/download/android  Twitter for Android  None
# 2           https://mobile.twitter.com      Twitter Web App  None
# 3   http://twitter.com/download/iphone   Twitter for iPhone  None
# 4  http://twitter.com/download/android  Twitter for Android  None
# 5           https://mobile.twitter.com      Twitter Web App  None
#
#   retweetedTweet  quotedTweet  \
# 0            NaN         None
# 2            NaN         None
# 3            NaN         None
# 4            NaN         None
# 5            NaN         None
#
#                                       mentionedUsers
# 0  [{'username': 'mini_bubbly', 'displayname': '🇨...
# 2  [{'username': 'MrStache9', 'displayname': 'Mr ...
# 3  [{'username': 'nationalpost', 'displayname': '...
# 4  [{'username': 'exposforever', 'displayname': '...
# 5  [{'username': 'journo_dale', 'displayname': 'D...
#
# [5 rows x 21 columns]

# %% [markdown]
# Having a look at a random sample of content.

# %%
cerb_df.iloc[10].content
# Out:
# "@RosieBarton Mr. O'Toole is not a leader, you need to actually care about Cdn's, I heard him say the CERB was a bad idea being released when it did. Won't answer what he would cut even though he says he agrees with half the measures. He's actually a bit of a joke!"

# %%
cerb_df.iloc[10].user
# Out:
# {'username': 'dmc1701',
#  'displayname': 'David McRae',
#  'id': 238865666,
#  'description': 'I am of the Odawa First Nation with some Scottish blood thrown in for good measure, I love people, politics! Hate Racists/Bullies!',
#  'rawDescription': 'I am of the Odawa First Nation with some Scottish blood thrown in for good measure, I love people, politics! Hate Racists/Bullies!',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2011-01-16T06:21:46+00:00',
#  'followersCount': 2563,
#  'friendsCount': 1421,
#  'statusesCount': 31945,
#  'favouritesCount': 34332,
#  'listedCount': 23,
#  'mediaCount': 205,
#  'location': 'Ottawa, Ontario Canada',
#  'protected': False,
#  'linkUrl': None,
#  'linkTcourl': None,
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1148297030529425408/aIQau2tO_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/238865666/1496371695',
#  'url': 'https://twitter.com/dmc1701'}

# %% [markdown]
# Note that all this user information is in json dictionary form and can be extracted.

# %%
cerb_df.iloc[10].user['username']
# Out:
# 'dmc1701'

# %% [markdown]
# Let's create a list of all usernames that can then be incorporated into the dataframe.

# %%
user_name_list = [cerb_df.iloc[i].user['username'] for i in range(len(cerb_df))]

# %%
cerb_df['user_name'] = user_name_list

# %%
cerb_df.tail()
# Out:
#                                                       url  \
# 255321  https://twitter.com/Son5000Yp/status/123397408...
# 255322  https://twitter.com/thekaptainbee/status/12339...
# 255324  https://twitter.com/patrick26539519/status/123...
# 255325  https://twitter.com/RAndrewsCWE/status/1233925...
# 255326  https://twitter.com/gmelaabez/status/123391390...
#
#                             date  \
# 255321 2020-03-01 04:35:22+00:00
# 255322 2020-03-01 03:51:20+00:00
# 255324 2020-03-01 01:36:07+00:00
# 255325 2020-03-01 01:21:03+00:00
# 255326 2020-03-01 00:36:15+00:00
#
#                                                   content  \
# 255321  @GretaThunberg I am certainly disgusted by the...
# 255322  @CaracciGmc @AdamParkhomenko -Lowest black une...
# 255324  @JustinTrudeau And unemployment rates through ...
# 255325  @RachelNotley Who do you think pays for our he...
# 255326  @diggingforoil @sammideedub @paulparrazzilvr @...
#
#                                           renderedContent  \
# 255321  @GretaThunberg I am certainly disgusted by the...
# 255322  @CaracciGmc @AdamParkhomenko -Lowest black une...
# 255324  @JustinTrudeau And unemployment rates through ...
# 255325  @RachelNotley Who do you think pays for our he...
# 255326  @diggingforoil @sammideedub @paulparrazzilvr @...
#
#                          id  \
# 255321  1233974083169247232
# 255322  1233963002250039296
# 255324  1233928976541736961
# 255325  1233925183477448705
# 255326  1233913906604756993
#
#                                                      user outlinks  \
# 255321  {'username': 'Son5000Yp', 'displayname': 'Yvet...       []
# 255322  {'username': 'thekaptainbee', 'displayname': '...       []
# 255324  {'username': 'patrick26539519', 'displayname':...       []
# 255325  {'username': 'RAndrewsCWE', 'displayname': 'Ry...       []
# 255326  {'username': 'gmelaabez', 'displayname': 'Gene...       []
#
#        tcooutlinks  replyCount  retweetCount  ...       conversationId  lang  \
# 255321          []           0             0  ...  1233775476998582278    en
# 255322          []           1             0  ...  1224907023990562816    en
# 255324          []           0             0  ...  1233890614879703041    en
# 255325          []           0             0  ...  1233866203568852992    en
# 255326          []           2             0  ...  1233827163666669568    en
#
#                                                    source  \
# 255321  <a href="http://twitter.com/download/android" ...
# 255322  <a href="http://twitter.com/download/iphone" r...
# 255324  <a href="http://twitter.com/download/iphone" r...
# 255325  <a href="http://twitter.com/download/iphone" r...
# 255326  <a href="http://twitter.com/download/iphone" r...
#
#                                   sourceUrl          sourceLabel media  \
# 255321  http://twitter.com/download/android  Twitter for Android  None
# 255322   http://twitter.com/download/iphone   Twitter for iPhone  None
# 255324   http://twitter.com/download/iphone   Twitter for iPhone  None
# 255325   http://twitter.com/download/iphone   Twitter for iPhone  None
# 255326   http://twitter.com/download/iphone   Twitter for iPhone  None
#
#        retweetedTweet quotedTweet  \
# 255321            NaN        None
# 255322            NaN        None
# 255324            NaN        None
# 255325            NaN        None
# 255326            NaN        None
#
#                                            mentionedUsers        user_name
# 255321  [{'username': 'GretaThunberg', 'displayname': ...        Son5000Yp
# 255322  [{'username': 'CaracciGmc', 'displayname': 'Gi...    thekaptainbee
# 255324  [{'username': 'JustinTrudeau', 'displayname': ...  patrick26539519
# 255325  [{'username': 'RachelNotley', 'displayname': '...      RAndrewsCWE
# 255326  [{'username': 'diggingforoil', 'displayname': ...        gmelaabez
#
# [5 rows x 22 columns]

# %% [markdown]
# ## EDA and Cleaning

# %% [markdown]
# Although our data does not appear to contain re-tweets, let's look at how many of the tweets have been retweeted by other users. About 79% of tweets appear to have no retweets.

# %%
cerb_df['retweetCount'].value_counts(normalize=True)
# Out:
# 0      0.793898
# 1      0.091625
# 2      0.033558
# 3      0.017794
# 4      0.011021
#          ...
# 383    0.000004
# 443    0.000004
# 442    0.000004
# 186    0.000004
# 572    0.000004
# Name: retweetCount, Length: 463, dtype: float64

# %% [markdown]
# **Unique Content**
# A crude measure to see if we are getting much duplicate content - this may not be because of retweets, but for other reasons such as bots etc.

# %%
print("Number of tweets with unique content:", len(cerb_df['content'].unique()))
print('Number of tweets with non-unique content:', cerb_df.shape[0]-len(cerb_df['content'].unique()))
# Out:
# Number of tweets with unique content: 239291
# Number of tweets with non-unique content: 1517

# %% [markdown]
# **Unique Timestamps**
# One prominent indicator of bot nets is that each bot account tweets content at the exact same time. Since our time_date info goes down to the millisecond we can measure this fairly precisely. Though of course there are also naturally coincidences - I will return to this question in later notebooks.

# %%
print("Number of tweets with unique timestamps:", len(cerb_df['date'].unique()))
print('Number of tweets with non-unique timestamps:', cerb_df.shape[0]-len(cerb_df['date'].unique()))
# Out:
# Number of tweets with unique timestamps: 235211
# Number of tweets with non-unique timestamps: 5597

# %% [markdown]
# Create a new simple date column.

# %%
cerb_df['simple_date'] = cerb_df.date.dt.date

# %%
cerb_df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/SandraLynnColl3/status/133...
# 2  https://twitter.com/bunmzi/status/133356432966...
# 3  https://twitter.com/D313131Daniel/status/13335...
# 4  https://twitter.com/Paulbyjove1/status/1333563...
# 5  https://twitter.com/GavinBamber/status/1333563...
#
#                        date  \
# 0 2020-12-01 00:12:39+00:00
# 2 2020-12-01 00:11:27+00:00
# 3 2020-12-01 00:08:32+00:00
# 4 2020-12-01 00:07:28+00:00
# 5 2020-12-01 00:07:00+00:00
#
#                                              content  \
# 0  @mini_bubbly In our Entire extended family, on...
# 2  @MrStache9 Many Canadians dont realize this. L...
# 3  @nationalpost @TheGrowthOp So that won’t cost ...
# 4  @exposforever @MJosling53 @erinotoole @PierreP...
# 5  @journo_dale Something like over $400 million ...
#
#                                      renderedContent                   id  \
# 0  @mini_bubbly In our Entire extended family, on...  1333564633320480769
# 2  @MrStache9 Many Canadians dont realize this. L...  1333564329665441793
# 3  @nationalpost @TheGrowthOp So that won’t cost ...  1333563595607699464
# 4  @exposforever @MJosling53 @erinotoole @PierreP...  1333563328040464385
# 5  @journo_dale Something like over $400 million ...  1333563211216424961
#
#                                                 user outlinks tcooutlinks  \
# 0  {'username': 'SandraLynnColl3', 'displayname':...       []          []
# 2  {'username': 'bunmzi', 'displayname': 'Mikel A...       []          []
# 3  {'username': 'D313131Daniel', 'displayname': '...       []          []
# 4  {'username': 'Paulbyjove1', 'displayname': 'Pa...       []          []
# 5  {'username': 'GavinBamber', 'displayname': 'Ga...       []          []
#
#    replyCount  retweetCount  ...  lang  \
# 0           0             0  ...    en
# 2           0             1  ...    en
# 3           0             0  ...    en
# 4           0             0  ...    en
# 5           0             0  ...    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="https://mobile.twitter.com" rel="nofo...
#
#                              sourceUrl          sourceLabel media  \
# 0  http://twitter.com/download/android  Twitter for Android  None
# 2           https://mobile.twitter.com      Twitter Web App  None
# 3   http://twitter.com/download/iphone   Twitter for iPhone  None
# 4  http://twitter.com/download/android  Twitter for Android  None
# 5           https://mobile.twitter.com      Twitter Web App  None
#
#   retweetedTweet quotedTweet  \
# 0            NaN        None
# 2            NaN        None
# 3            NaN        None
# 4            NaN        None
# 5            NaN        None
#
#                                       mentionedUsers        user_name  \
# 0  [{'username': 'mini_bubbly', 'displayname': '🇨...  SandraLynnColl3
# 2  [{'username': 'MrStache9', 'displayname': 'Mr ...           bunmzi
# 3  [{'username': 'nationalpost', 'displayname': '...    D313131Daniel
# 4  [{'username': 'exposforever', 'displayname': '...      Paulbyjove1
# 5  [{'username': 'journo_dale', 'displayname': 'D...      GavinBamber
#
#   simple_date
# 0  2020-12-01
# 2  2020-12-01
# 3  2020-12-01
# 4  2020-12-01
# 5  2020-12-01
#
# [5 rows x 23 columns]

# %% [markdown]
# Let's have a look at location data. Data acquired from snscrape does not include same geolocation data as one could acquire from Tweepy, however only 1-2% of tweets are understood to have geolocation data, but users can also post their location in user information, so let's see what it looks like.

# %%
locations = [cerb_df.iloc[i].user['location'] for i in range(len(cerb_df))]

# %%
len(locations)
# Out:
# 240808

# %%
from collections import Counter

# %%
loc_counts = Counter(locations)

# %%
len(loc_counts)
# Out:
# 16928

# %% [markdown]
# That's nearly 17,000 unique locations that appear too messy to engineer into a useful feature for the time being.

# %%
loc_counts
# Out:
# Counter({'Canada': 20716,
#          '': 65564,
#          'Kingston, Ontario': 497,
#          'North Vancouver': 87,
#          'Calgary, Alberta': 3054,
#          'British Columbia Canada': 32,
#          'Fredericton New Brunswick': 1,
#          'Ottawa, Ontario Canada': 24,
#          'Safe refuge for some Albertans': 162,
#          'Ontario, Canada': 6404,
#          'Rothesay, NB, Canada': 1,
#          'Winnipeg, Manitoba': 1467,
#          'he / she': 4,
#          'Calgary': 868,
#          'mississauga': 9,
#          'Kelowna, British Columbia': 160,
#          'Toronto, Ontario': 10325,
#          '... da\' "Bert"': 76,
#          'Greater Vancouver, British Columbia': 71,
#          'Saskatoon': 113,
#          'CANADA █ ♥ █': 16,
#          'Northwestern Ontario': 8,
#          'Winnipeg, MB': 256,
#          'Ottawa, ON': 313,
#          'Dartford, UK': 25,
#          '🇨🇦': 441,
#          'ヘソでも噛んで死んじゃえばぁ?': 475,
#          'Alberta, Canada': 2125,
#          'Amherstburg, Ontario ': 40,
#          'Ottawa': 1414,
#          'Treaty 7 / Alberta / 🇨🇦': 12,
#          'Drifting...': 31,
#          'Ottawa, Ontario': 3399,
#          'Vancouver, British Columbia': 2901,
#          'Ajax, Ontario': 91,
#          'Edmonton, Alberta': 2146,
#          'Nova Scotia, Canada': 380,
#          'Northern Alberta, Canada': 26,
#          'GTA, Canada': 47,
#          'p.e.i.': 22,
#          'Petrofascia': 2,
#          'H/\\LIF/\\X, Nova Scotia, Canada': 36,
#          'Hamilton, Ontario': 1015,
#          'Southside Latveria': 133,
#          'Edmonton, AB, Canada': 93,
#          'Burlington, Ontario': 160,
#          'Edmonton': 565,
#          'Encroaching parallel dimension': 3,
#          'Vichy Canada': 3,
#          'http://freethepresscanada.org/': 7,
#          'Denver, CO': 6,
#          '99 Problems Blvd': 24,
#          'CANADA': 172,
#          'Canada, USA': 134,
#          'ontario': 42,
#          'Pittsburgh jr ': 20,
#          'Qo’noS': 13,
#          'ÜT: 54.43139,-110.201267': 14,
#          'Richmond, British Columbia': 87,
#          'England': 10,
#          'World': 291,
#          'Stolen Songhees Territory': 5,
#          'Miriams living room': 4,
#          'Ontario': 1222,
#          'The Cloud': 6,
#          'Brandon, MB': 162,
#          'Mississauga, Ontario': 605,
#          'N Alberta': 1,
#          '179 King St E, Oshawa': 6,
#          'Quinte West, Ontario': 50,
#          'Rusty Nail Farm': 2,
#          'south west NB': 4,
#          'queens, ny': 2,
#          'Blaine, WA': 2,
#          'Gotham City': 6,
#          'Saskatchewan, Canada': 388,
#          'worst case ontario, canada': 6,
#          'Kitchener, Ontario': 415,
#          'Ottawa, Canada': 601,
#          'Alberta, Awesome ': 4,
#          'Edmonton Alberta': 57,
#          'Calgary, Alberta, Canada ': 24,
#          'Campbell River, British Columb': 15,
#          'Republic of Alberta': 30,
#          'Halifax, Nova Scotia': 861,
#          'Vancouver Island': 151,
#          'So-called Canada': 2,
#          'Toronto, ON': 892,
#          'Calgary/Okotoks': 1,
#          'Earth 2': 3,
#          'YEG & USA ': 13,
#          'Niitsitapi territory': 20,
#          'Alberta': 681,
#          'Disabled community of 🇨🇦': 168,
#          'Canuckistan': 8,
#          'Crescent Beach BC': 1,
#          "exalt kingz' house": 3,
#          'high road to enlightenment': 193,
#          'Earth': 556,
#          'England/Wales': 4,
#          'Toronto, Canada': 1678,
#          'yeg Canada': 2,
#          'Tampa, FL': 51,
#          'Hawaii': 15,
#          'St Joseph de Beauce': 22,
#          'Great Lakes': 12,
#          'Oakville, Ontário': 1,
#          'Earth ': 40,
#          'Hades': 5,
#          'Toronto': 5995,
#          'Edmonton, Alberta-Treaty 6 ': 14,
#          'London, England': 108,
#          'Here ': 3,
#          'hazara, she/her, 20': 3,
#          'she/her • gay • 21 • 🐝 • ℓ': 1,
#          'Southwestern Ontario': 32,
#          'Niagara Region, Canada': 6,
#          'Ontario Canada': 492,
#          'unceded land, south coast BC': 16,
#          'St. Catharines, Ontario': 271,
#          'Mont-Laurier, Québec': 1,
#          'Quebec': 11,
#          'NWO Ground Zero': 3,
#          'Denver, Toronto, Ottawa': 1213,
#          'Erin, Ontario': 5,
#          'preferably asleep': 1,
#          'Cork, Ireland': 7,
#          'University of Toronto | Music': 1,
#          'Waterloo, Ontario': 316,
#          'she/her | lesbian': 1,
#          'valley in the shadow of death': 20,
#          'Backwoods of Ontario,Canada  ': 16,
#          'Alberta Canada': 89,
#          'he/him': 54,
#          'Cuckcanada': 4,
#          'Vaughan, Ontario': 92,
#          'Delta Quandrant': 11,
#          'Ww2 germany it seams': 2,
#          'Bathurst, New Brunswick': 4,
#          'Minneapolis, MN': 63,
#          'Ibadan, Nigeria': 4,
#          'Caledon, ON 🇨🇦': 1,
#          'Montréal, Québec, Canada': 45,
#          'New Brunswick, Canada': 319,
#          'Barcelona, Catalunya': 21,
#          'Canada ': 319,
#          'Sol-Earther': 3,
#          'Lahore, Pakistan': 3,
#          'Annapolis Valley First Nation': 3,
#          'Mumbai': 9,
#          'British Columbia, Canada': 1396,
#          'St Paul, MN': 35,
#          'In My Bag 🧑🏿\u200d🦯': 1,
#          'over the hills & far away': 19,
#          'Texas, USA': 33,
#          'Toronto, and Vancouver Canada': 72,
#          'North Carolina, USA': 11,
#          'Manitoba': 77,
#          'Your moms': 12,
#          'Port Coquitlam': 18,
#          'St. Albert, Alberta': 142,
#          "Active fr Oct'19 #STOPCovid19": 2,
#          'Trail, British Columbia': 33,
#          'My butt spans the planet~': 2,
#          'Sydney, New South Wales': 25,
#          'Undisclosed': 21,
#          'Airdrie, Alberta': 100,
#          'Bowman Nation ': 15,
#          'Little Mountain, Vancouver': 19,
#          'George Soros Floating Tower': 17,
#          'ottawa': 39,
#          ' ': 69,
#          'Cold Lake, Alberta': 14,
#          'mtl // tor': 7,
#          'Myrnam, AB': 1,
#          'Bellevue, WA  & West Vancouver': 1,
#          'New-Brunswick Canada ': 1,
#          'Windsor, Ontario': 351,
#          'The Maze': 8,
#          'Toronto, Ontario, Canada': 534,
#          'South River, Ontario, Canada': 17,
#          'ON 🇨🇦': 8,
#          'in the computer': 1,
#          'Port Alberni, BC': 79,
#          'Montreal, Quebec Canada ': 3,
#          'petsmart’s cat section': 1,
#          'welland': 2,
#          'Treaty 6, Alabamaberta': 13,
#          'New Paltz, NY': 3,
#          'Toronto, Ontario/USA': 8,
#          'Anaheimcucamungabookreview': 3,
#          'United States': 269,
#          'Montreal': 510,
#          'Vinland, Canada': 13,
#          'Treaty Four Territory': 27,
#          "St. John's": 246,
#          'TORONTO': 94,
#          'TDot': 1,
#          'Ottawa, Ontario, Canada': 428,
#          'Montreal, Quebec, Canada': 25,
#          'Los Angeles, California ': 1,
#          'bag': 89,
#          'Indigenous Land  ': 2,
#          'Instagram: @AJDelgado13': 1,
#          'Brit #expat in Canada & US fam': 7,
#          'vancouver': 45,
#          'Maple Ridge & Langley': 6,
#          'Newmarket, Ontario': 51,
#          'Your girl’s house ': 1,
#          'British Columbia': 285,
#          'Kelowna': 21,
#          'Midgar': 3,
#          'Dallas, TX': 20,
#          'Unionville, Ontario': 29,
#          'she/her - treaty 7': 7,
#          'Vancouver | Canada': 1,
#          'Cambridge ON.': 7,
#          'Vancouver BC': 128,
#          'planet earth': 145,
#          'Treaty 7/Alberta': 10,
#          'Happy to see you!  ': 197,
#          'World-a human universal family': 15,
#          ':Akaripog:': 2,
#          'North Western Ontario': 15,
#          'St. Paul Ab': 1,
#          'Calgary, AB, Canada': 34,
#          'Coast, prairies or in between': 16,
#          'Alderaan': 26,
#          'The Vancouver Model #CullenIsComing #CommunityNotCommodity': 54,
#          'Wynnes scorched earth': 37,
#          'Finland': 4,
#          'Haldemand Tract 🌎 🇨🇦': 93,
#          'Toronto/GTA/Hamilton ON': 81,
#          'United Kingdom': 131,
#          'York South-Weston': 9,
#          'London, Ontario': 834,
#          'your mothers bedroom': 7,
#          'Kelowna BC': 4,
#          'Napoli': 1,
#          'Annapolis Royal, Nova Scotia': 12,
#          'Walmart heat suppressant aisle': 13,
#          '✨✨✨✨': 1,
#          'Brighton Soon to be a tent': 79,
#          'art not mine don,t own shit': 121,
#          '🇵🇭trans mlm (he/they)': 2,
#          'Owen Sound, Ontario': 16,
#          'Unlocking my Mangekyo': 1,
#          'BC': 138,
#          'birdscreeches.tumblr.com': 2,
#          'anxious hippocampus': 1,
#          'How to get out of Florida?': 6,
#          'Hell': 45,
#          'Winnipeg': 423,
#          'Regina, Saskatchewan': 291,
#          'Where Jesus told me': 5,
#          'Manitoba, Canada': 429,
#          'Republic of the Philippines': 7,
#          'Oakville, Ontario, Canada': 21,
#          '🌯': 4,
#          'Ucluelet - Nanaimo BC Canada': 7,
#          'Antler River, Ontario ': 1,
#          'Fraser Valley, BC': 8,
#          'Pictou County, N.S. Canada': 1,
#          'Langley, British Columbia': 105,
#          'Lima, OH': 1,
#          'the mind': 1,
#          'HALIFAX/PEI ɐpɐuɐϽ': 7,
#          'Newfoundland & Labrador': 15,
#          'Wayne, NE': 1,
#          'West Kelowna ': 2,
#          'Bali - Vancouver': 1,
#          'ongole': 1,
#          'Coronatopia': 21,
#          'Xbox One': 35,
#          'Oz': 7,
#          'Sunnyvale': 3,
#          'Greater Vancouver A': 7,
#          'Ontario, CA': 360,
#          'Vancouver': 1054,
#          'Sault Ste Marie Ontario': 1,
#          '🇻🇳': 1,
#          'name in dn | 19 | any prns': 1,
#          'BC, Canada': 189,
#          'Cariboo, British Columbia': 2,
#          'Calgary, Treaty 7, Canada': 3,
#          'Nunya Avenue': 7,
#          'Kitchener, ON': 30,
#          'Toronto 🇨🇦': 49,
#          'funko pop zone': 1,
#          'calgary , alberta, canada': 3,
#          'Nepean, Ontario, Canada': 3,
#          'Montreal, QC': 72,
#          'Banff Airdrie': 1,
#          'Sault Ste. Marie, Ontario': 38,
#          'they/them|eighteen|¹/?𝒹𝓈': 6,
#          'blackpink in your area': 1,
#          'Intercourse, PA': 3,
#          'Gatineau, QC': 16,
#          'Markham, Ontario': 316,
#          'Your Anus': 16,
#          'The Jerk Store': 8,
#          'Interior of British Columbia': 1,
#          'Halifax N.S.': 21,
#          'Yur Mum, America': 4,
#          'New Brunswick': 42,
#          'Vancouver, Canada': 375,
#          'London, Ontario, Canada': 157,
#          'Peterborough, Ontario': 157,
#          'kitchen': 10,
#          'montreal': 47,
#          'Canadian': 16,
#          'Newmarket, Ontario, Canada': 56,
#          'Cambridge/Niagara/WPB': 1,
#          'Hong Kong': 8,
#          'Ste Anne Mb ': 26,
#          'Somewhere in Canada': 17,
#          'Chaos • Cerberus': 4,
#          '·.·´¯Allah is amazing·.·´¯`·.·': 4,
#          'He/Him/They/Them': 2,
#          'Fort Knox CONDO Aurora Ontario': 5,
#          'The Netherlands': 11,
#          'Jylland, Denmark': 16,
#          'they': 1,
#          'Searching...': 1,
#          '404 Not Found': 1,
#          'Up in space  🚀': 1,
#          '2021, so done with 2020': 5,
#          "Keegan's Mom's House": 6,
#          'Global': 183,
#          'mtl, kanata • she/her': 1,
#          'Mannville Ab': 1,
#          'Montréal / Regina': 4,
#          'she/her, 23 ♡©️marmaladica': 1,
#          'Oujé-Bougoumou, Québec': 1,
#          'Surrey, BC Canada': 17,
#          '@CityofVancouver BC': 2,
#          'India': 87,
#          'Manitoba, So called Canada': 1,
#          'brampton': 6,
#          'Phillipines': 12,
#          '6 adjacent': 1,
#          'Mountain side': 7,
#          'Sovereign Republic of Me': 7,
#          'Waterloo ON Canada': 1,
#          'echo beach. real & imagined.': 1,
#          'screw face capital 📍': 2,
#          'Someplace': 1,
#          'yyz': 11,
#          'out here': 6,
#          'Goulds, Newfoundland, Canada': 15,
#          'Charlottetown': 73,
#          "Tio'tia:ke/Mooninyaang (MTL)": 9,
#          ' Anishinaabewaki (Ottawa,ON)': 10,
#          'Hogwarts': 3,
#          'The Zoo Called Planet Earth': 11,
#          'Tillsonburg, ON, Canada': 45,
#          'WPG 📍 MTL': 3,
#          'Nakatomi Plaza': 3,
#          'Coquitlam, British Columbia': 51,
#          '118th Ave': 6,
#          'frew': 1,
#          'Film and Politcs @ RyeU': 2,
#          'Victoria, British Columbia': 550,
#          ', USA✝️🇺🇸': 1,
#          'Tkaronto ': 7,
#          'Saskatoon, SK': 84,
#          'Internet': 27,
#          'iPhone: 43.607212,-79.632034': 1,
#          'Victoria, BC': 304,
#          'Everywhere': 81,
#          'Chicago, IL': 30,
#          'Kitchener and Waterloo, Canada': 20,
#          'Lake Simcoe': 31,
#          'Mississauga, ON': 32,
#          'Toronto ': 663,
#          'Cobourg, Ontario Canada': 47,
#          'Regina, Canada': 7,
#          'At the Pool in the D.R.': 2,
#          'she/her - 21': 5,
#          'Oshawa, Ontario': 180,
#          'Unceded land, Syilx Nation': 12,
#          'Saskatoon, Saskatchewan': 293,
#          'My desk ': 3,
#          'Inside': 3,
#          'Greater Sudbury / Grand Sudbur': 36,
#          'tkaronto': 27,
#          'World Wide': 33,
#          'Vancouver, BC': 922,
#          'Stoughton, Saskatchewan': 2,
#          'La Canada Flintridge, CA': 6,
#          'Wherever Tyler the Creator is': 2,
#          'Calgary Alberta': 45,
#          'ocean': 5,
#          'The Okanagan': 7,
#          'Woolwich, Ontario ': 1,
#          'Treaty 7 Land': 13,
#          'T-Dot': 18,
#          'Global Citizen': 16,
#          'Halifax, NS': 182,
#          'Brampton, ON, Canada': 2,
#          'West of the liberal stronghold': 8,
#          'Centre of the Universe, ON ': 28,
#          'Cambridge': 9,
#          'Calgary/ Treaty 7 territory': 9,
#          'Universe': 24,
#          'Alberta, Canada 🇨🇦': 13,
#          'Gaa-Okosing, Abya Yala': 7,
#          'COVID-19 Wastelands of #YEG': 1,
#          'Oklahoma, USA': 2,
#          'Leeds, England': 3,
#          'ohio': 3,
#          'Edmonton, Alberta, Canada': 314,
#          'ottawa, Canada': 3,
#          'England, United Kingdom': 21,
#          'Downtown, Vancouver': 17,
#          'Broken Brain': 36,
#          'The Northside, Fredericton, NB': 10,
#          'Treaty 6 Territory': 30,
#          'Canada 🇨🇦 ': 85,
#          'Canada, Toronto': 3,
#          'Richmond Hill, Ontario': 75,
#          'Toronto, ON CANADA': 10,
#          'Wasaga Beach, Ontario': 89,
#          'Peterborough, Ontario, Canada': 22,
#          '21 • they/them': 3,
#          'Oakville, Ontario': 148,
#          'mtl': 14,
#          'Amsterdam, The Netherlands': 11,
#          'White Rock, BC': 21,
#          'Charlottetown, Prince Edward I': 25,
#          'Langley, BC - Victoria, BC': 3,
#          'Battleford, Sk': 1,
#          'Alcatraz ': 37,
#          'Ahembramsmy': 1,
#          'T Dot': 4,
#          'The Peg': 4,
#          'Niagara': 32,
#          'Scotland': 2,
#          '🇨🇦 ': 68,
#          '505.....for now': 1,
#          'International zone': 11,
#          'Bell Island, Nfld. Canada🚢': 1,
#          'Kitchener, ON, Canada': 14,
#          'Curve Lake First Nation 35': 1,
#          'Whitby, Ontario': 266,
#          'Guelph, Ontario': 243,
#          'Victoria, BC-Charlottetown, PE': 2,
#          'Montreal, Canada': 128,
#          'Thunder Science Co. (DL room)': 31,
#          'North Vancouver, British Columbia': 30,
#          'Beamsville, ON': 35,
#          'Planet Earth': 167,
#          'Zootonia': 2,
#          'Toronto & GTA': 10,
#          'Ottawa, ON, Canada': 118,
#          'God Fearing Man ': 1,
#          'LEAFS NATION': 62,
#          'London,Toronto,Boston': 4,
#          'toronto': 398,
#          'Sudbury ON': 52,
#          'Vaudreuil-Soulanges, Québec': 12,
#          'on site': 1,
#          '17 they/them': 5,
#          'Gourev': 1,
#          'Cold North': 2,
#          'Sydney, Australia': 13,
#          'Toronto, Ontario Canada': 48,
#          'Maple Ridge, B.C.': 5,
#          'Visit Amazing Polly': 2,
#          'chicago': 4,
#          'maamaa akii': 1,
#          'Red State Canada': 3,
#          'Fat Bat Cave (Canada)': 1,
#          'Windsor, Ontario, Canada': 42,
#          'dauphin,manitoba': 25,
#          'Wood Buffalo, Alberta': 34,
#          'Prince George, BC': 33,
#          'Twilight Zone': 5,
#          'icon: @philipposole': 1,
#          'Nova Scotia': 126,
#          'Leafs/Jays/Raptors Nation': 1,
#          'Wellington North, Ontario': 4,
#          'Global Citizen ': 2,
#          'Windsor Ont. Canada SinCity2': 1,
#          'Moon': 3,
#          'Delta BC': 19,
#          'Montréal, Québec': 1112,
#          'Red Deer, Alberta': 184,
#          'Dryden, ON, CANADA': 1,
#          'Leafsnation, Canada': 1,
#          'Lost in the Supermarket': 22,
#          'Tkaronto/Toronto': 23,
#          'Richmond, BC, Canada': 13,
#          'York Region': 62,
#          'Pothole Central': 1,
#          'Toronto via Hawkesbury Beach': 3,
#          'Torontoish': 14,
#          'GTHA ': 2,
#          ' Ontario': 22,
#          'CANADA 🇨🇦 | USA 🇺🇸': 1,
#          'Nuu-Chah-Nulth Territories ': 21,
#          'Northern Turtle Island/Canada': 32,
#          'Maple Ridge': 3,
#          'Whitby, Ontario, Canada': 6,
#          'Calgary, AB': 495,
#          'Ottawa Valley - Canada': 13,
#          'Ottawa/Toronto': 10,
#          'Centre of the Universe🇨🇦🇬🇧': 6,
#          'Toronto, Ontario, CANADA': 5,
#          'Niagara Center ': 1,
#          'Here': 51,
#          'moose jaw sask': 1,
#          'North of 49': 21,
#          'Kitchener On': 27,
#          'Lək̓ʷəŋən territories / YYJ': 1,
#          'Bowen Island, British Columbia': 1,
#          'Niagara Falls, Ontario': 99,
#          'Michigan, USA': 17,
#          'Kitchener-Waterloo, Ontario': 2,
#          'Toronto & Quito, Ecuador': 4,
#          'Pickering, Ontario': 52,
#          'Newfoundland and Labrador, Can': 174,
#          'Vancouver, BC, Canada': 164,
#          'he/they': 3,
#          'Ladner/Tsawwassen': 13,
#          'Montague, Prince Edward Island': 1,
#          ' 43°39\'58.1"N 79°20\'03.4"W': 4,
#          'Thorold Ontario': 9,
#          'Barrie, Ontario': 225,
#          'Sudbury, ON': 26,
#          'Timmins, Ontario': 24,
#          'Guelph, On.': 9,
#          'North Bay, Ontario': 64,
#          'Sault Ste. Marie, ON': 13,
#          'North America': 267,
#          'Somewhere in Canada ': 6,
#          'Alberta, Canada, eh.': 1,
#          'Thunder Bay, ON, Canada 🇨🇦': 2,
#          'Comox, BC': 2,
#          'Watch online': 62,
#          'Etobicoke, Canada': 6,
#          'T-Dot Baby (Toronto, Canada)': 1,
#          'Lacombe, Alberta': 35,
#          'Somewhere north of the #400': 32,
#          'Salmon Arm': 29,
#          'Keremeos, British Columbia': 33,
#          'Princeton, BC': 31,
#          'Oak Bay, B.C., Canada': 33,
#          'Lake Cowichan': 93,
#          'Abbotsford': 40,
#          'Burns Lake, British Columbia': 31,
#          'Nelson, B.C.': 33,
#          'Maple Ridge, B.C, Canada': 36,
#          'Rimbey, Alberta': 27,
#          'Duncan B.C.': 32,
#          'Victoria BC Canada': 50,
#          'Saanich': 36,
#          'Stettler': 40,
#          'Clearwater, BC, Canada': 30,
#          'Port Alberni': 36,
#          'Summerland, BC': 29,
#          'Campbell River, B.C.': 31,
#          'Comox Valley': 30,
#          'Victoria, B.C.': 76,
#          'Vanderhoof, British Columbia': 32,
#          'Parksville, B.C., Canada': 30,
#          'Fort St. James, B.C.': 31,
#          'Ladysmith, BC, Canada': 32,
#          'Trail, B.C.': 37,
#          'Nanaimo, British Columbia': 131,
#          'Penticton': 45,
#          'Kelowna, B.C.': 38,
#          'Surrey, B.C.': 38,
#          'Chilliwack': 37,
#          'Sidney, B.C.': 33,
#          'One Hundred Mile House': 27,
#          'Chemainus, BC': 30,
#          'Sicamous, British Columbia': 30,
#          'Castlegar, BC': 31,
#          'Prince Rupert, B.C.': 32,
#          'Mission, British Columbia': 42,
#          'Sooke, B.C.': 31,
#          'North Okanagan, B.C.': 35,
#          'Sylvan Lake, Alberta': 34,
#          'Winnipeg ': 13,
#          'Fredericton, New Brunswick': 118,
#          'Citizen of the World': 25,
#          '43.243732,-79.806877': 1,
#          'America': 7,
#          '#LeafNation #MagicFairyStyle ': 2,
#          'Vancouver 溫哥華, Canada 加拿大 🇨🇦': 35,
#          ' 🇨🇦': 7,
#          'Cape Breton, Nova Scotia': 94,
#          'New Glasgow, Nova Scotia': 13,
#          ' Regent Park - Toronto ': 1,
#          'LV-426': 58,
#          'Lost City of Atlantis': 1,
#          'On the ₿locc': 5,
#          'North Vancouver, B.C.': 18,
#          "settler in K'jipuktuk (HFX)": 41,
#          'Calgary, Alberta, ': 2,
#          'somewhere in Canada ': 16,
#          'Turtle Island': 74,
#          'New Westminster': 44,
#          'YEGAS': 2,
#          'Canada City,Canada': 3,
#          'Concrete Jungle, Tomorrowland': 4,
#          'Burnaby, B.C.': 9,
#          'Grey County, Ontario': 5,
#          '1 Yonge St., Toronto, Canada': 135,
#          'Sunshine Coast BC': 15,
#          'Hamilton, ont , canada': 1,
#          'B the glue in UR relationships': 1,
#          'Northern Ontario': 24,
#          'Sugar Cane': 2,
#          'Regina, SK': 107,
#          'Regina, SK ': 7,
#          'Kamloops, British Columbia': 139,
#          'Vancity': 11,
#          'Kelowna, BC': 76,
#          'Lancaster, England': 1,
#          'ALBERTA': 31,
#          'Abbotsford, British Columbia': 44,
#          'Guelph, Canada': 4,
#          'Just outside of Saskatoon, SK': 1,
#          ', Canada ontario': 16,
#          'quebec city centre ville de  charlesbourg': 5,
#          'Live in Halifax NS': 3,
#          'Greater Toronto Area': 52,
#          'new scotland': 13,
#          'no': 9,
#          'Toronto. ': 3,
#          "Unceded K'ómoks land(settler) ": 10,
#          "St. John's, NL": 141,
#          'Not far from Toronto, ON': 21,
#          'Venezuela': 4,
#          'Strathroy, Ontario': 3,
#          'The world i was brought into': 4,
#          'Downtown Canada': 176,
#          'jay | she/they | 25': 5,
#          'On Eric’s face, obviously': 2,
#          'San Francisco, CA': 59,
#          'Parañaque': 1,
#          'Eurasia': 1,
#          'StateofStupidity Planet🌎': 1,
#          '🇱🇨🇨🇦': 1,
#          'London': 66,
#          'Western Canada': 138,
#          '♎︎☉⇡ ♐︎☾': 5,
#          'B.C canada ': 9,
#          'Calgary Alberta Canada': 31,
#          'Brampton, Ontario': 391,
#          'Saskatoon, SK, Canada': 30,
#          'Medicine Hat': 18,
#          'VanCity': 11,
#          'Bragg Creek, Alberta': 4,
#          'Twin Peaks': 8,
#          'Shady Spring, WV': 1,
#          'downtown': 3,
#          'Sherbrooke, Québec, Canada': 3,
#          'Chippewa & Washington': 1,
#          'Rocky Mountain House, Alberta': 2,
#          'Weimar, Canada ': 8,
#          'Vancouver BC, Canada': 16,
#          'Medicine Hat, Alberta': 63,
#          'TORONTA': 1,
#          'King of fhe Kingdom': 1,
#          'Turdchester, UK': 1,
#          'GTA, Ontario': 13,
#          'Ponamogoatitjg/ Dartmouth, NS': 30,
#          'Neo Seoul': 14,
#          'Kwikwetlem\n🌲🌲🌲': 12,
#          'Unceded Algonquin Territory': 85,
#          'Jackson’s Point, Ontario ': 2,
#          'Canada, US and Brazil': 2,
#          'USA': 119,
#          'West Coast ': 2,
#          'YYC': 56,
#          'Treaty 7 land.Calgary, Alberta': 7,
#          '"vomitorium" Alberta': 44,
#          'Lockport, MB': 1,
#          'Adamson Barbecue': 1,
#          'Intersection of Bravery and Freedom': 62,
#          'Treaty 7 (Canada)': 2,
#          'Vancouver B.C.': 26,
#          'Perth, Ontario': 96,
#          '8707 Dufferin Street, Unit 10 ': 6,
#          'Edmonton, AB': 211,
#          'In front of the fridge': 1,
#          ' Alberta': 30,
#          'instagram: @cielxnoel': 2,
#          ' Ontario CANADA': 2,
#          'Under the Northern Lights 🇨🇦': 1,
#          'https://tinylink.net/LZBkS': 5,
#          'Canada ❤️ Edmonton 🙋🏻\u200d♀️☀️⚖️': 54,
#          'Next door to Alex Trebek': 87,
#          ' Alberta / Cali/Alaska/Florida': 4,
#          'New York, NY': 87,
#          'Toronto, Ontario. Canada': 18,
#          'Washington, DC': 68,
#          'Waterloo, Canada': 14,
#          'The Shire': 6,
#          'ÜT: 50.415269,-105.601237': 12,
#          'Matrix, pastilla roja 🎭': 4,
#          'Canada & Việt Nam': 9,
#          'Penticton, British Columbia': 46,
#          'Clive AB': 1,
#          'Hamilton, ON, Canada': 6,
#          'Winterpeg': 15,
#          'Kamloops ': 2,
#          'Red Deer, AB': 39,
#          'Middle Of Nowhere, Canada': 2,
#          'YGK': 48,
#          'East York Ontario': 7,
#          'Canada and the world': 19,
#          'Peterborough, Ontario,Canada': 2,
#          'toronto ca': 5,
#          'Shivering Isles': 1,
#          'Lethbridge, Alberta': 132,
#          'Around.': 5,
#          'Edmonton ': 20,
#          'SK, BC, FL, and in YOUR mind!': 4,
#          'Canada-Wide': 1,
#          'Humber River Black Creek': 46,
#          'N.B ': 47,
#          'Horsehead, Alberta': 8,
#          'OntariOWE': 12,
#          'Unceded FN Lands, BC, Canada ': 61,
#          'London, UK': 14,
#          'La Ronge, SK': 1,
#          'Markdale Ontario': 17,
#          'Werewolf Land': 3,
#          'まほやく・あんスタ • エリオスR ＊ they/she': 2,
#          'BX': 1,
#          "St.John's, NL": 1,
#          'Cloverdale, BC': 6,
#          'The Middle-ish, Scotland ': 1,
#          'Global Citizen.': 72,
#          'Estadio Santiago Bernabeu': 1,
#          "Mi'kma'ki": 52,
#          "Head of St. Marg's Bay, NS": 35,
#          'canada': 298,
#          'Email: mrtoast72info@gmail.com': 1,
#          'Yeg': 5,
#          'Sj': 1,
#          'Infinite IKEA': 1,
#          'जै हिंद की सेना🇮🇳वंदे मातरम्': 56,
#          'ÜT: 43.77321,-79.56914': 7,
#          'St Clair Beach Ontario Canada.': 4,
#          'Adult Neurology': 1,
#          'Tkaronto': 158,
#          'Calgary, Alberta.': 6,
#          'Kingston, NS': 2,
#          'Milton, Ontario': 133,
#          'Land Mass that was Canada': 38,
#          "Livin' in a #bikelane #OEVldn": 3,
#          'toronto, ontario': 37,
#          'YHZ': 2,
#          'Edmonton,Alberta': 9,
#          'Thornhill, Ontario': 7,
#          'out.side': 2,
#          "summoner's rift": 1,
#          'Estevan No. 5, Saskatchewan': 3,
#          'Citywire Financial Publishing': 1,
#          'Laval, QC, H7K 3M4, Canada': 4,
#          'Everywhere, Ontario': 1,
#          'City of London, London': 5,
#          'london': 5,
#          'Canada, MTL': 2,
#          'GTA': 83,
#          'CBG': 2,
#          'website:': 42,
#          'Centre of the universe ': 1,
#          'Nashville, TN': 8,
#          'milton ont canada': 1,
#          'Gaggleville, Sherwood Forest': 1,
#          'New Rochelle NY': 1,
#          'Your Interweb Viewing Screen': 1,
#          'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA': 1,
#          'Sudbury, Ontario': 122,
#          'Pakistan': 33,
#          'Denver,co': 1,
#          'she/her 23': 1,
#          'Stoney Creek Ontario': 7,
#          'ÜT: 50.953278,-113.978785': 28,
#          'ICON @ DEERTHINGIES': 1,
#          'YYC GAL': 11,
#          'Terminus': 1,
#          'crystal city mb': 6,
#          'Camrose, Alberta': 21,
#          'Toronto and Ottawa, Canada': 2,
#          'yeg': 8,
#          'calgary, alberta': 12,
#          'Cuba': 3,
#          'Old School Runescape': 1,
#          'ur mom': 1,
#          'Edmonton, Alberta (Treaty 6)': 1,
#          'South of Detroit': 1,
#          'Florida, USA': 42,
#          'Iqaluit, Nunavut': 20,
#          'never been here before have u?': 1,
#          'Toronto, Canada YYZ': 4,
#          'Huron Bruce, Ontario': 23,
#          'Memphis, TN': 1,
#          'Fort St. John': 5,
#          'Right where I want to be': 1,
#          'she/her': 153,
#          'Victoria, B.C. Canada': 5,
#          'Around': 4,
#          'Just N of Helleville Ontario': 1,
#          'Rockwood, ON  Canada': 54,
#          'Bellingham,  Washington ': 1,
#          'Sunshine Coast': 5,
#          'ÜT: 53.561556,-113.590942': 1,
#          'UTC−04:00': 2,
#          'Heart of Alberta': 7,
#          "Satan's balls, BC": 10,
#          'YYC - Treaty 7 - The Beltline': 1,
#          'Adelaide | Australia ': 1,
#          'Kincardine, Ontario, Canada': 1,
#          'Quarantined Earth': 32,
#          'Settler on Treaty 6 territory': 1,
#          'Etobicoke': 170,
#          'Planet Earth, Dar al-Harb.': 4,
#          'Saskatoon, Sk, Canada': 2,
#          'missing at sea': 2,
#          'hockey-stick distance, Canada': 4,
#          'Castlegar, British Columbia': 5,
#          '18+ || ms / mv || PJO RP ': 1,
#          'Woodbridge, Ontario': 4,
#          'telegram @itsfuckingdani': 1,
#          'Pound Town': 1,
#          'West Virginia, USA': 2,
#          '365 Bloor St. E., Toronto, ON': 31,
#          'Morrisburg': 3,
#          'saskatoon, sk': 1,
#          'Keswick Ridge, NB': 3,
#          'Toronto Ontario Canada': 52,
#          'Toronto, Ont. ': 17,
#          'Ottawa On': 3,
#          '#extinction chronicle⌛': 18,
#          'Alt-left Twilight zone': 3,
#          'Greater Vancouver': 170,
#          'nyc / nj': 2,
#          'Minas Gerais, Brasil': 1,
#          'Thunder Bay,Ontario,Canada.': 3,
#          "Canada's capital, sometimes": 19,
#          'Mississippi, USA': 3,
#          'Miami, Florida': 7,
#          'We the North': 11,
#          'West Vancouver': 32,
#          'Melmac': 5,
#          'Calgary, Alberta, Canada': 292,
#          'Victoria': 29,
#          'Online 24/7. Not even kidding.': 6,
#          'Dartmouth, NS': 75,
#          'wormhole ': 1,
#          'Halifax, Canada': 13,
#          'treaty 1 territory settler': 2,
#          'Clare, Ireland': 2,
#          'some 905 town': 3,
#          'yeg 🍁': 1,
#          'nowhere': 4,
#          'Treaty 7 Territory, Canada': 2,
#          'Niagara Falls, ON': 18,
#          'Gainesville, FL': 1,
#          'CANADA - USA - EUROPE -ARG': 1,
#          'Cascadia': 28,
#          'None of your business.': 3,
#          'out there': 2,
#          'Toronto, Mississauga ': 4,
#          '2A-603 Superior Street': 6,
#          'Thornhill, Ontario, Canada': 3,
#          'Strathmore': 5,
#          'Winnipeg, MB, Canada': 41,
#          'ALBERTA ': 46,
#          '┌┴┐': 3,
#          'C*A*N*A*D*A': 1,
#          'The only habitable planet': 9,
#          'they/them': 79,
#          'Hidden Cloud': 1,
#          'NB,Canada': 1,
#          'Ontario 416-905': 2,
#          'on a journey OM & OFF the Mat': 4,
#          'TORONTO , ON , CANADA': 4,
#          'Weimar Republic': 124,
#          'Amsterdam, Rockwood': 1,
#          'North Point Douglas': 1,
#          'Moncton NB': 11,
#          'stolen land': 10,
#          'Millbrook, Ontario': 1,
#          'YQR': 10,
#          'downtown canada': 14,
#          'The 905': 7,
#          'On 📲 in St. Albert, 🆎 🇨🇦': 8,
#          'Regina, SK Canada': 6,
#          'Mumbai, India': 50,
#          'Lake of the Woods, Ontario': 8,
#          'On the roof in a clown suit.': 3,
#          'Milky Way Galaxy': 8,
#          'Weyburn': 5,
#          'Toronto area': 25,
#          'swamp': 1,
#          'DΛRTMOUTH, NS 🇨🇦': 14,
#          'GTA Ontario, Canada': 29,
#          'Eastern Passage, Nova Scotia': 1,
#          'Québec, Canada': 218,
#          "Mi'kma'ki / Halifax": 2,
#          'San Antonio, TX': 11,
#          'Inside bebe': 1,
#          'Outside Leafs viewing region': 1,
#          'Odessa': 5,
#          'Markdale, ON': 10,
#          'Unceded lands West of Montréal': 11,
#          'Punamu’kwati’jk': 1,
#          'h8 it here ': 11,
#          'Greater Napanee, Ontario': 2,
#          'Inverary, Ontario, Canada ': 6,
#          'UK': 36,
#          "KJIPUKTUK (Halifax) Mi'kma'ki": 8,
#          'Somewhere in British Columbia': 2,
#          "America's hat": 9,
#          'Maritime Provinces, Canada': 16,
#          'Gary, IN': 1,
#          'New York, USA': 61,
#          'Toronto and Hamilton.': 1,
#          'Yellowknife, NT, Canada': 17,
#          'The Great White North.': 3,
#          'Nanton-Calgary': 1,
#          'The Welfare State of Trudeau': 20,
#          'sad trans girl || 22': 1,
#          'New Delhi, India': 20,
#          'Indian Head, Saskatchewan': 2,
#          'Toronto Canada': 79,
#          'Westlock, Alberta': 2,
#          'B Meenakshipuram, India': 2,
#          'West coast, canada': 1,
#          '🌧🌧': 25,
#          '🇨🇦🏳️\u200d🌈 Vancouver': 1,
#          'San Jose, CA (Silicon Valley)': 1,
#          'Twitter': 41,
#          'Pembroke, Ontario 🇨🇦': 5,
#          'Burnaby, BC': 11,
#          'New Zealand': 17,
#          'Orion Arm  MilkyWay Galaxy': 1,
#          'Home': 8,
#          'GOLDEN TRIANGLE': 27,
#          'binaville': 6,
#          'ATLTS02.Tech , Waterloo.': 2,
#          'Toronto, ON, Canada': 138,
#          'pleaseleora@gmail.com': 1,
#          'Kitsilano, Vancouver': 21,
#          'Australia': 63,
#          'Regina, Saskatchewan Canada ': 10,
#          'lincoln, nebraska': 1,
#          'Humane Society': 10,
#          'Brantford ON': 10,
#          'Hamilton, Ontario, Canada': 87,
#          'clarington': 6,
#          'Vancouver, BC, Canada.': 1,
#          ' Canada': 374,
#          'Bruce,Grey,Huron,Perth ON': 1,
#          'Wabasca,Alberta': 1,
#          'the moon ': 9,
#          'New Vancouver': 79,
#          'The Bigland': 8,
#          '21 • she/her': 5,
#          'Small lake town BC (from Wpg)': 1,
#          'Durham, Ontario': 53,
#          'Uranus': 3,
#          'change this please uwu': 2,
#          'Somewhere in KY': 1,
#          '🐯💜🐰': 1,
#          'Smiths Falls, Ontario': 18,
#          'Mars': 60,
#          'University of Regina, Canada.': 2,
#          'Las Vegas, NV': 22,
#          'Brampton-Ontario-Canada': 75,
#          'around the world': 16,
#          'East St. Paul, Manitoba': 14,
#          'Saint John, New Brunswick': 86,
#          'Montréal,QC & Rotonda West,FL': 3,
#          'Ballerup, Danmark': 1,
#          'Newfoundland ': 21,
#          '49 degrees N, 122 W': 1,
#          'East Luther Grand Valley, Ontario': 1,
#          'Toronto ON': 48,
#          'Harrison Hot Springs BC': 1,
#          'Victoria, BC, Canada': 100,
#          'SouthWest BC': 12,
#          'Montreal, Quebec': 74,
#          'York, England': 2,
#          'Relocated Hamiltonian.': 2,
#          'ÜT: 53.522345,-113.583108': 4,
#          'Surrey, BC CANADA': 5,
#          'calgary': 43,
#          'Fredericton NB': 9,
#          'East Coast, Canada': 8,
#          'Saskatchewan': 102,
#          'Somewhere near Barrie Ont...': 1,
#          ...})

# %% [markdown]
# Just in case I want to look at this later I will incorporate it as a new dataframe column.

# %%
cerb_df['location'] = locations

# %% [markdown]
# One more look at a random slice of the data.

# %%
cerb_df.iloc[72000:72010]
# Out:
#                                                      url  \
# 76690  https://twitter.com/JoyceMurray/status/1295557...
# 76691  https://twitter.com/BigAlx/status/129555715940...
# 76692  https://twitter.com/gla4refugees/status/129555...
# 76693  https://twitter.com/minsooklee/status/12955565...
# 76694  https://twitter.com/NewthAndrea/status/1295555...
# 76695  https://twitter.com/A44037682871/status/129555...
# 76696  https://twitter.com/bryanyuBC/status/129555465...
# 76697  https://twitter.com/liminal67/status/129555441...
# 76698  https://twitter.com/NewthAndrea/status/1295553...
# 76699  https://twitter.com/NNorma192/status/129555378...
#
#                            date  \
# 76690 2020-08-18 03:05:18+00:00
# 76691 2020-08-18 03:04:31+00:00
# 76692 2020-08-18 03:04:27+00:00
# 76693 2020-08-18 03:01:56+00:00
# 76694 2020-08-18 02:58:58+00:00
# 76695 2020-08-18 02:58:00+00:00
# 76696 2020-08-18 02:54:34+00:00
# 76697 2020-08-18 02:53:38+00:00
# 76698 2020-08-18 02:51:51+00:00
# 76699 2020-08-18 02:51:07+00:00
#
#                                                  content  \
# 76690  ‘@Bill_Morneau - capable and caring - has serv...
# 76691  I just signed in support of converting the CER...
# 76692  @JustinTrudeau @Bill_Morneau “Bill Money” than...
# 76693  We are in a global pandemic, 3 million Canadia...
# 76694  @204Girl0574 I am a small business owner and I...
# 76695  @battousai1130 @LaurenToronto4 I hear you. No ...
# 76696  Why the end of CERB could jolt consumer spendi...
# 76697  I just signed in support of converting the CER...
# 76698  @204Girl0574 There are checks and balances.  I...
# 76699  @kimcreynolds1 @TheJasonPugh New Brunswickers!...
#
#                                          renderedContent                   id  \
# 76690  ‘@Bill_Morneau - capable and caring - has serv...  1295557353539022848
# 76691  I just signed in support of converting the CER...  1295557159401459718
# 76692  @JustinTrudeau @Bill_Morneau “Bill Money” than...  1295557141986607104
# 76693  We are in a global pandemic, 3 million Canadia...  1295556508139298816
# 76694  @204Girl0574 I am a small business owner and I...  1295555760701747201
# 76695  @battousai1130 @LaurenToronto4 I hear you. No ...  1295555517864120322
# 76696  Why the end of CERB could jolt consumer spendi...  1295554653069795328
# 76697  I just signed in support of converting the CER...  1295554418994274307
# 76698  @204Girl0574 There are checks and balances.  I...  1295553971168456705
# 76699  @kimcreynolds1 @TheJasonPugh New Brunswickers!...  1295553786539397125
#
#                                                     user  \
# 76690  {'username': 'JoyceMurray', 'displayname': 'Jo...
# 76691  {'username': 'BigAlx', 'displayname': 'Alex Mo...
# 76692  {'username': 'gla4refugees', 'displayname': 'B...
# 76693  {'username': 'minsooklee', 'displayname': 'Min...
# 76694  {'username': 'NewthAndrea', 'displayname': 'An...
# 76695  {'username': 'A44037682871', 'displayname': 'I...
# 76696  {'username': 'bryanyuBC', 'displayname': 'brya...
# 76697  {'username': 'liminal67', 'displayname': 'Davi...
# 76698  {'username': 'NewthAndrea', 'displayname': 'An...
# 76699  {'username': 'NNorma192', 'displayname': 'NNor...
#
#                                                 outlinks  \
# 76690                                                 []
# 76691  [https://www.leahgazan.ca/basicincomemotion?re...
# 76692                                                 []
# 76693  [https://twitter.com/PnPCBC/status/12955080447...
# 76694                                                 []
# 76695                                                 []
# 76696  [https://www.theglobeandmail.com/business/arti...
# 76697  [https://www.leahgazan.ca/basicincomemotion?re...
# 76698                                                 []
# 76699                                                 []
#
#                      tcooutlinks  replyCount  retweetCount  ...  \
# 76690                         []           2             4  ...
# 76691  [https://t.co/SWYtQEtgU8]           0             0  ...
# 76692                         []           0             0  ...
# 76693  [https://t.co/zYYJq67FvW]           1             7  ...
# 76694                         []           1             3  ...
# 76695                         []           1             0  ...
# 76696  [https://t.co/RHgQ6DvNrX]           0             0  ...
# 76697  [https://t.co/HsUbilQeUw]           0             1  ...
# 76698                         []           1             0  ...
# 76699                         []           2             1  ...
#
#                                                   source  \
# 76690  <a href="http://twitter.com/download/iphone" r...
# 76691  <a href="http://twitter.com/download/iphone" r...
# 76692  <a href="http://twitter.com/download/iphone" r...
# 76693  <a href="http://twitter.com/download/iphone" r...
# 76694  <a href="http://twitter.com/download/iphone" r...
# 76695  <a href="https://mobile.twitter.com" rel="nofo...
# 76696  <a href="http://twitter.com/download/iphone" r...
# 76697  <a href="http://twitter.com/download/android" ...
# 76698  <a href="http://twitter.com/download/iphone" r...
# 76699  <a href="http://twitter.com/download/iphone" r...
#
#                                  sourceUrl          sourceLabel media  \
# 76690   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76691   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76692   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76693   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76694   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76695           https://mobile.twitter.com      Twitter Web App  None
# 76696   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76697  http://twitter.com/download/android  Twitter for Android  None
# 76698   http://twitter.com/download/iphone   Twitter for iPhone  None
# 76699   http://twitter.com/download/iphone   Twitter for iPhone  None
#
#       retweetedTweet                                        quotedTweet  \
# 76690            NaN                                               None
# 76691            NaN                                               None
# 76692            NaN                                               None
# 76693            NaN  {'url': 'https://twitter.com/PnPCBC/status/129...
# 76694            NaN                                               None
# 76695            NaN                                               None
# 76696            NaN                                               None
# 76697            NaN                                               None
# 76698            NaN                                               None
# 76699            NaN                                               None
#
#                                           mentionedUsers     user_name  \
# 76690  [{'username': 'Bill_Morneau', 'displayname': '...   JoyceMurray
# 76691                                               None        BigAlx
# 76692  [{'username': 'JustinTrudeau', 'displayname': ...  gla4refugees
# 76693                                               None    minsooklee
# 76694  [{'username': '204Girl0574', 'displayname': '🇨...   NewthAndrea
# 76695  [{'username': 'battousai1130', 'displayname': ...  A44037682871
# 76696                                               None     bryanyuBC
# 76697                                               None     liminal67
# 76698  [{'username': '204Girl0574', 'displayname': '🇨...   NewthAndrea
# 76699  [{'username': 'kimcreynolds1', 'displayname': ...     NNorma192
#
#        simple_date           location
# 76690   2020-08-18   Vancouver Quadra
# 76691   2020-08-18
# 76692   2020-08-18    Quebec, England
# 76693   2020-08-18            Toronto
# 76694   2020-08-18  Brighton, Ontario
# 76695   2020-08-18     The hinterland
# 76696   2020-08-18
# 76697   2020-08-18    Toronto, Canada
# 76698   2020-08-18  Brighton, Ontario
# 76699   2020-08-18
#
# [10 rows x 24 columns]

# %% [markdown]
# This gives us a fairly good sense of what the data looks like from a high level. Let's pickle the dataframe to use in the next notebook for text preprocessing and tokenization to extract word embeddings.

# %%
with open('cerb_df.pickle', 'wb') as to_write:
    pickle.dump(cerb_df, to_write)
